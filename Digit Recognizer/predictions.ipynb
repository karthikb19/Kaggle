# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "drive/My Drive/MNIST"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/MNIST'
# /content/drive/My Drive/MNIST

# %%
import pandas as pd
df_test = pd.read_csv("test.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_sub_off = pd.read_csv("submit_off.csv")
df_off = pd.read_csv("submit_off1.csv")

# %%
sub_off_pred = df_sub_off["Label"]
sub_off = df_off["Label"]

# %%
from tqdm import tqdm
diff_preds = []

for i in tqdm(range(len(sub_off_pred))):
  if sub_off_pred[i] != sub_off[i]:
    diff_preds.append(i)
# Out:
# 100%|██████████| 28000/28000 [00:00<00:00, 40138.61it/s]

# %%
len(diff_preds)
# Out:
# 204

# %%
diff_preds
# Out:
# [165,
#  538,
#  844,
#  912,
#  1059,
#  1098,
#  1261,
#  1389,
#  1468,
#  1503,
#  1907,
#  2087,
#  2099,
#  2122,
#  2149,
#  2226,
#  2553,
#  2646,
#  2743,
#  2751,
#  2870,
#  3217,
#  3277,
#  3288,
#  3290,
#  3520,
#  3529,
#  3625,
#  3700,
#  3723,
#  3899,
#  4018,
#  4239,
#  4341,
#  4583,
#  4609,
#  4802,
#  4927,
#  4949,
#  4994,
#  5214,
#  5784,
#  5830,
#  5957,
#  6000,
#  6212,
#  6527,
#  6682,
#  6979,
#  7063,
#  7242,
#  7341,
#  7456,
#  7657,
#  8031,
#  8119,
#  8296,
#  8316,
#  8326,
#  8403,
#  8667,
#  8674,
#  9051,
#  9202,
#  9443,
#  9514,
#  9577,
#  9582,
#  9814,
#  9855,
#  9924,
#  9981,
#  10362,
#  10391,
#  10394,
#  10860,
#  10865,
#  11078,
#  11370,
#  11535,
#  11539,
#  11596,
#  11622,
#  11666,
#  11697,
#  11729,
#  11752,
#  12086,
#  12165,
#  12365,
#  12527,
#  12583,
#  12620,
#  12884,
#  12896,
#  13129,
#  13434,
#  13559,
#  13590,
#  13844,
#  13868,
#  13877,
#  14014,
#  14258,
#  14459,
#  14551,
#  14635,
# ...

# %%
from matplotlib import pyplot as plt
cnt = 6682
print("Official Image label is:| ", sub_off_pred[cnt])
print("Submission 2 Image label is:| ", sub_off[cnt])
plt.imshow(df_test[13844][:, :, 0])
# Out:
# Official Image label is:|  8
# Submission 2 Image label is:|  0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 13844
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
diff_preds
# Out:
# [165,
#  275,
#  341,
#  554,
#  668,
#  760,
#  789,
#  844,
#  912,
#  1183,
#  1235,
#  1261,
#  1389,
#  1422,
#  1468,
#  1503,
#  1586,
#  1770,
#  1882,
#  1900,
#  1953,
#  2087,
#  2125,
#  2149,
#  2251,
#  2416,
#  2611,
#  2637,
#  2646,
#  2697,
#  2727,
#  3015,
#  3217,
#  3255,
#  3277,
#  3288,
#  3290,
#  3295,
#  3520,
#  3526,
#  3529,
#  3700,
#  3733,
#  3844,
#  3899,
#  4080,
#  4239,
#  4341,
#  4390,
#  4583,
#  4609,
#  4765,
#  4802,
#  4949,
#  5038,
#  5155,
#  5237,
#  5554,
#  5561,
#  5571,
#  5647,
#  5830,
#  5957,
#  5966,
#  6265,
#  6403,
#  6673,
#  6919,
#  6979,
#  7026,
#  7149,
#  7169,
#  7242,
#  7264,
#  7657,
#  7837,
#  8164,
#  8199,
#  8296,
#  8337,
#  8667,
#  8674,
#  8838,
#  8868,
#  9051,
#  9202,
#  9261,
#  9577,
#  9582,
#  9585,
#  9673,
#  9744,
#  9855,
#  9900,
#  9924,
#  9981,
#  10074,
#  10304,
#  10344,
#  10362,
#  10394,
#  10865,
#  11123,
#  11231,
#  11539,
#  11596,
#  11622,
#  11697,
#  11762,
#  11862,
# ...
